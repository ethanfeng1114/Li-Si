# %%
import matplotlib.pyplot as plt
from matplotlib import style
import pybamm
from Durdel2023 import get_test_parameter_values, get_final_parameter_values, get_OG_parameter_values

# %%
"Primary Active Material"
rho_si = 2.336 #from ref (supplementary material)
wt_si = .679 #% from ref
"Secondary Active Material"
rho_c6 = 2.255 # (C-NERGYTM KS6L)
wt_c6 = .199
"Inactive Material"
rho_cb = 2.00 #from ref
wt_cb = 0.02 # from ref
rho_lipaa = 1.2 #ref
wt_lipaa = 0.082 # ref
rho_cmc = 1.6 #ref
wt_cmc = 0.002 #ref

v_tot  = wt_si/rho_si + wt_c6/rho_c6 + wt_cb/rho_cb + wt_lipaa/rho_lipaa + wt_cmc/rho_cmc
v_si = wt_si/rho_si
v_c6 = wt_c6/rho_c6
v_im = wt_c6/rho_c6 + wt_lipaa/rho_lipaa + wt_cmc/rho_cmc

eps_si = 0.5 * v_si / v_tot #times 0.5 to account for porosity (eps_ely = 0.5)
eps_c6 = 0.5 * v_c6 / v_tot
eps_am = 0.5* (v_si + v_c6) / v_tot

cell_volume = 0.0124*0.124*(92e-06 + 1.2e-05 + 2.6e-05 + 136e-06 +1.5e-05)

print("Volume fraction of Si: ", eps_si
      , "Volume fraction of C6: ", eps_c6, "Volume fraction of AM: ", eps_am, "cell volume: ", cell_volume)
# Out:
# Volume fraction of Si:  0.31697725057239584 Volume fraction of C6:  0.09623602768522001 Volume fraction of AM:  0.41321327825761583 cell volume:  4.3206559999999995e-07

# %%
model = pybamm.lithium_ion.DFN(
    {"particle phases": ("2", "1"),
     "open-circuit potential": (("single", "current sigmoid"), "single"),
     #"working electrode": "negative",
     "SEI": "none",
     "lithium plating": "none",
    }
)

model.print_parameter_info()
# Out:
# ┌──────────────────────────────────────────────────────────────────┬────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# │ Parameter                                                        │ Type of parameter                                                                                                                                                                                                      │
# ├──────────────────────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ Reference temperature [K]                                        │ Parameter                                                                                                                                                                                                              │
# │ Nominal cell capacity [A.h]                                      │ Parameter                                                                                                                                                                                                              │
# │ Electrode width [m]                                              │ Parameter                                                                                                                                                                                                              │
# │ Electrode height [m]                                             │ Parameter                                                                                                                                                                                                              │
# │ Positive electrode Bruggeman coefficient (electrolyte)           │ Parameter                                                                                                                                                                                                              │
# │ Upper voltage cut-off [V]                                        │ Parameter                                                                                                                                                                                                              │
# │ Negative electrode thickness [m]                                 │ Parameter                                                                                                                                                                                                              │
# │ Negative electrode Bruggeman coefficient (electrolyte)           │ Parameter                                                                                                                                                                                                              │
# │ Ideal gas constant [J.K-1.mol-1]                                 │ Parameter                                                                                                                                                                                                              │
# │ Positive electrode Bruggeman coefficient (electrode)             │ Parameter                                                                                                                                                                                                              │
# │ Negative electrode Bruggeman coefficient (electrode)             │ Parameter                                                                                                                                                                                                              │
# │ Secondary: Maximum concentration in negative electrode [mol.m-3] │ Parameter                                                                                                                                                                                                              │
# │ Number of electrodes connected in parallel to make a cell        │ Parameter                                                                                                                                                                                                              │
# │ Lower voltage cut-off [V]                                        │ Parameter                                                                                                                                                                                                              │
# │ Initial concentration in electrolyte [mol.m-3]                   │ Parameter                                                                                                                                                                                                              │
# │ Primary: Maximum concentration in negative electrode [mol.m-3]   │ Parameter                                                                                                                                                                                                              │
# │ Number of cells connected in series to make a battery            │ Parameter                                                                                                                                                                                                              │
# │ Maximum concentration in positive electrode [mol.m-3]            │ Parameter                                                                                                                                                                                                              │
# │ Separator Bruggeman coefficient (electrolyte)                    │ Parameter                                                                                                                                                                                                              │
# │ Positive electrode thickness [m]                                 │ Parameter                                                                                                                                                                                                              │
# │ Faraday constant [C.mol-1]                                       │ Parameter                                                                                                                                                                                                              │
# │ Initial temperature [K]                                          │ Parameter                                                                                                                                                                                                              │
# │ Separator thickness [m]                                          │ Parameter                                                                                                                                                                                                              │
# │ Secondary: Negative particle radius [m]                          │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Thermodynamic factor                                             │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Temperature [K]'                                                                                                                              │
# │ Ambient temperature [K]                                          │ FunctionParameter with inputs(s) 'Distance across electrode width [m]', 'Distance across electrode height [m]', 'Time [s]'                                                                                             │
# │ Cation transference number                                       │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Temperature [K]'                                                                                                                              │
# │ Primary: Negative electrode OCP [V]                              │ FunctionParameter with inputs(s) 'Primary: Negative particle stoichiometry'                                                                                                                                            │
# │ Positive electrode active material volume fraction               │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Secondary: Initial concentration in negative electrode [mol.m-3] │ FunctionParameter with inputs(s) 'Radial distance (r) [m]', 'Through-cell distance (x) [m]'                                                                                                                            │
# │ Secondary: Negative electrode delithiation OCP [V]               │ FunctionParameter with inputs(s) 'Secondary: Negative particle stoichiometry'                                                                                                                                          │
# │ Primary: Negative particle radius [m]                            │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Secondary: Negative electrode lithiation OCP [V]                 │ FunctionParameter with inputs(s) 'Secondary: Negative particle stoichiometry'                                                                                                                                          │
# │ Positive particle diffusivity [m2.s-1]                           │ FunctionParameter with inputs(s) 'Positive particle stoichiometry', 'Temperature [K]'                                                                                                                                  │
# │ Secondary: Negative electrode OCP entropic change [V.K-1]        │ FunctionParameter with inputs(s) 'Negative particle stoichiometry'                                                                                                                                                     │
# │ Positive electrode OCP entropic change [V.K-1]                   │ FunctionParameter with inputs(s) 'Positive particle stoichiometry'                                                                                                                                                     │
# │ Primary: Negative electrode active material volume fraction      │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Positive electrode conductivity [S.m-1]                          │ FunctionParameter with inputs(s) 'Temperature [K]'                                                                                                                                                                     │
# │ Electrolyte diffusivity [m2.s-1]                                 │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Temperature [K]'                                                                                                                              │
# │ Negative electrode porosity                                      │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Positive electrode OCP [V]                                       │ FunctionParameter with inputs(s) 'Positive particle stoichiometry'                                                                                                                                                     │
# │ Current function [A]                                             │ FunctionParameter with inputs(s) 'Time [s]'                                                                                                                                                                            │
# │ Primary: Negative electrode OCP entropic change [V.K-1]          │ FunctionParameter with inputs(s) 'Negative particle stoichiometry'                                                                                                                                                     │
# │ Positive electrode exchange-current density [A.m-2]              │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Positive particle surface concentration [mol.m-3]', 'Maximum positive particle surface concentration [mol.m-3]', 'Temperature [K]'            │
# │ Positive particle radius [m]                                     │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Primary: Initial concentration in negative electrode [mol.m-3]   │ FunctionParameter with inputs(s) 'Radial distance (r) [m]', 'Through-cell distance (x) [m]'                                                                                                                            │
# │ Negative electrode conductivity [S.m-1]                          │ FunctionParameter with inputs(s) 'Temperature [K]'                                                                                                                                                                     │
# │ Initial concentration in positive electrode [mol.m-3]            │ FunctionParameter with inputs(s) 'Radial distance (r) [m]', 'Through-cell distance (x) [m]'                                                                                                                            │
# │ Separator porosity                                               │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Secondary: Negative electrode active material volume fraction    │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Electrolyte conductivity [S.m-1]                                 │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Temperature [K]'                                                                                                                              │
# │ Secondary: Negative particle diffusivity [m2.s-1]                │ FunctionParameter with inputs(s) 'Secondary: Negative particle stoichiometry', 'Temperature [K]'                                                                                                                       │
# │ Positive electrode porosity                                      │ FunctionParameter with inputs(s) 'Through-cell distance (x) [m]'                                                                                                                                                       │
# │ Secondary: Negative electrode exchange-current density [A.m-2]   │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Negative particle surface concentration [mol.m-3]', 'Secondary: Maximum negative particle surface concentration [mol.m-3]', 'Temperature [K]' │
# │ Primary: Negative electrode exchange-current density [A.m-2]     │ FunctionParameter with inputs(s) 'Electrolyte concentration [mol.m-3]', 'Negative particle surface concentration [mol.m-3]', 'Primary: Maximum negative particle surface concentration [mol.m-3]', 'Temperature [K]'   │
# │ Primary: Negative particle diffusivity [m2.s-1]                  │ FunctionParameter with inputs(s) 'Primary: Negative particle stoichiometry', 'Temperature [K]'                                                                                                                         │
# └──────────────────────────────────────────────────────────────────┴────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘

# %%
param = pybamm.ParameterValues(get_test_parameter_values())

# param.update(
#     {
#         "Primary: Negative electrode active material volume fraction": 0.09623602768522001, # primary
#         "Secondary: Negative electrode active material volume fraction": 0.31697725057239584,
#         "Negative electrode porosity": 0.5,
#     }
#     )

# %%
experiment = pybamm.Experiment(
    [
        (
            "Discharge at C/50 until 3.0 V",
            #"Rest for 2 hours",
            "Charge at C/50 until 4.2 V",
        ),
    ]
)

# %%
sim = pybamm.Simulation(
    model,
    parameter_values=param,
    experiment = experiment,
    #solver=pybamm.CasadiSolver(mode='safe', return_solution_if_failed_early=True)
)
solution = sim.solve()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Subtraction(0x33cfc8a9cce70a20, -, children=['concatenation((3.0 * Primary: Negative electrode active material volume fraction / Primary: Negative particle radius [m]) * 2.0 * Primary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - (Primary: Negative electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Primary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])) + (3.0 * Secondary: Negative electrode active material volume fraction / Secondary: Negative particle radius [m]) * 2.0 * Secondary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])), broadcast(0.0), (3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode surface potential difference [V] - (Positive electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))) / Faraday constant [C.mol-1]', 'div(-concatenation(Negative electrode porosity ** Negative electrode Bruggeman coefficient (electrolyte), Separator porosity ** Separator Bruggeman coefficient (electrolyte), Positive electrode porosity ** Positive electrode Bruggeman coefficient (electrolyte)) * Electrolyte diffusivity [m2.s-1] * grad(Porosity times concentration [mol.m-3](Negative electrode porosity times concen ...
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Division(0xdaaf94a8f574597, /, children=['concatenation((3.0 * Primary: Negative electrode active material volume fraction / Primary: Negative particle radius [m]) * 2.0 * Primary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - (Primary: Negative electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Primary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])) + (3.0 * Secondary: Negative electrode active material volume fraction / Secondary: Negative particle radius [m]) * 2.0 * Secondary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])), broadcast(0.0), (3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode surface potential difference [V] - (Positive electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])))', 'Faraday constant [C.mol-1]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Concatenation(-0x48a5d9cd38cabaae, concatenation, children=['(3.0 * Primary: Negative electrode active material volume fraction / Primary: Negative particle radius [m]) * 2.0 * Primary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - (Primary: Negative electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Primary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])) + (3.0 * Secondary: Negative electrode active material volume fraction / Secondary: Negative particle radius [m]) * 2.0 * Secondary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))', 'broadcast(0.0)', '(3.0 * Positive electrode active material volume fraction / Positive particle radius [m]) * 2.0 * Positive electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Positive electrode surface potential difference [V] - (Positive electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Positive electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Positive particle concentration [mol.m-3]) / Maximum concentration in positive electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Addition(-0x5b749cfd553e73b, +, children=['(3.0 * Primary: Negative electrode active material volume fraction / Primary: Negative particle radius [m]) * 2.0 * Primary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - (Primary: Negative electrode OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Primary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative primary particle concentration [mol.m-3]) / Primary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))', '(3.0 * Secondary: Negative electrode active material volume fraction / Secondary: Negative particle radius [m]) * 2.0 * Secondary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Multiplication(0x6c593a72bf0f34ad, *, children=['3.0 * Secondary: Negative electrode active material volume fraction / Secondary: Negative particle radius [m]', '2.0 * Secondary: Negative electrode exchange-current density [A.m-2] * sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Multiplication(-0x3c3b685f0d7874f, *, children=['2.0 * Secondary: Negative electrode exchange-current density [A.m-2]', 'sinh(0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K]))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Sinh(0x7b340963cb9958ec, function (sinh), children=['0.5 * Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Multiplication(0x269e7d8ac97b0189, *, children=['0.5', 'Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))) / broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Division(0x6ff1db91d341482d, /, children=['Faraday constant [C.mol-1] * (Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))))', 'broadcast(Ideal gas constant [J.K-1.mol-1] * Ambient temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Multiplication(-0x1af54baccd92eec5, *, children=['Faraday constant [C.mol-1]', 'Negative electrode surface potential difference [V] - ((0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Subtraction(0x35b5fbfa21ed454d, -, children=['Negative electrode surface potential difference [V]', '(0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))) + (0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Addition(-0x7c7c999f69021e14, +, children=['(0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))) * (Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))', '(0.5 - (0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m])))) * (Secondary: Negative electrode delithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10))))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Multiplication(0x196c71cfdaefad07, *, children=['0.5 + 0.5 * tanh(-100.0 * Current function [A] / (Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]))', 'Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1] + 1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Addition(-0x568acea14113e7b4, +, children=['Secondary: Negative electrode lithiation OCP [V] + broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1]', '1e-06 * (1.0 / (maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)) + 1.0 / (-1.0 + maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)))'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: Addition(-0x13558eb06ed40b68, +, children=['Secondary: Negative electrode lithiation OCP [V]', 'broadcast(Ambient temperature [K] - Reference temperature [K]) * Secondary: Negative electrode OCP entropic change [V.K-1]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:658, in ParameterValues.process_symbol(self, symbol)
#     657 try:
# --> 658     return self._processed_symbols[symbol]
#     659 except KeyError:
#
# KeyError: FunctionParameter(-0x72f628bfeaa25be6, Secondary: Negative electrode lithiation OCP [V], children=['maximum(minimum(boundary value(Negative secondary particle concentration [mol.m-3]) / Secondary: Maximum concentration in negative electrode [mol.m-3], 0.9999999999), 1e-10)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']})
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 7
#       1 sim = pybamm.Simulation(
#       2     model,
#       3     parameter_values=param,
#       4     experiment = experiment,
#       5     #solver=pybamm.CasadiSolver(mode='safe', return_solution_if_failed_early=True)
#       6 )
# ----> 7 solution = sim.solve()
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/simulation.py:547, in Simulation.solve(self, t_eval, solver, save_at_cycles, calc_esoh, starting_solution, initial_soc, callbacks, showprogress, inputs, t_interp, **kwargs)
#     545 elif self.operating_mode == "with experiment":
#     546     callbacks.on_experiment_start(logs)
# --> 547     self.build_for_experiment(
#     548         initial_soc=initial_soc, inputs=inputs, solve_kwargs=kwargs
#     549     )
#     550     if t_eval is not None:
#     551         pybamm.logger.warning(
#     552             "Ignoring t_eval as solution times are specified by the experiment"
#     553         )
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/simulation.py:349, in Simulation.build_for_experiment(self, initial_soc, inputs, solve_kwargs)
#     347     return
#     348 else:
# --> 349     self._set_up_and_parameterise_experiment(solve_kwargs)
#     351     # Can process geometry with default parameter values (only electrical
#     352     # parameters change between parameter values)
#     353     self._parameter_values.process_geometry(self._geometry)
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/simulation.py:224, in Simulation._set_up_and_parameterise_experiment(self, solve_kwargs)
#     222 self.experiment_unique_steps_to_model = {}
#     223 for step in self.experiment.unique_steps:
# --> 224     parameterised_model = step.process_model(self._model, parameter_values)
#     225     self.experiment_unique_steps_to_model[step.basic_repr()] = (
#     226         parameterised_model
#     227     )
#     229 # Set up rest model if experiment has start times
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/experiment/step/base_step.py:371, in BaseStep.process_model(self, model, parameter_values)
#     368     new_parameter_values["Ambient temperature [K]"] = self.temperature
#     370 # Parameterise the model
# --> 371 parameterised_model = new_parameter_values.process_model(
#     372     new_model, inplace=False
#     373 )
#     375 return parameterised_model
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:497, in ParameterValues.process_model(self, unprocessed_model, inplace)
#     495     pybamm.logger.verbose(f"Processing parameters for {variable!r} (rhs)")
#     496     new_variable = self.process_symbol(variable)
# --> 497     new_rhs[new_variable] = self.process_symbol(equation)
#     498 model.rhs = new_rhs
#     500 new_algebraic = {}
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:660, in ParameterValues.process_symbol(self, symbol)
#     658     return self._processed_symbols[symbol]
#     659 except KeyError:
# --> 660     processed_symbol = self._process_symbol(symbol)
#     661     self._processed_symbols[symbol] = processed_symbol
#     663     return processed_symbol
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:799, in ParameterValues._process_symbol(self, symbol)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:799, in <listcomp>(.0)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:660, in ParameterValues.process_symbol(self, symbol)
#     658     return self._processed_symbols[symbol]
#     659 except KeyError:
# --> 660     processed_symbol = self._process_symbol(symbol)
#     661     self._processed_symbols[symbol] = processed_symbol
#     663     return processed_symbol
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:799, in ParameterValues._process_symbol(self, symbol)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:799, in <listcomp>(.0)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
#     [... skipping similar frames: ParameterValues.process_symbol at line 660 (13 times), <listcomp> at line 799 (12 times), ParameterValues._process_symbol at line 799 (12 times)]
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:799, in ParameterValues._process_symbol(self, symbol)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:799, in <listcomp>(.0)
#     793 # Functions, BinaryOperators & Concatenations
#     794 elif (
#     795     isinstance(symbol, pybamm.Function)
#     796     or isinstance(symbol, pybamm.Concatenation)
#     797     or isinstance(symbol, pybamm.BinaryOperator)
#     798 ):
# --> 799     new_children = [self.process_symbol(child) for child in symbol.children]
#     800     return symbol.create_copy(new_children)
#     802 # Variables: update scale
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:660, in ParameterValues.process_symbol(self, symbol)
#     658     return self._processed_symbols[symbol]
#     659 except KeyError:
# --> 660     processed_symbol = self._process_symbol(symbol)
#     661     self._processed_symbols[symbol] = processed_symbol
#     663     return processed_symbol
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/parameters/parameter_values.py:745, in ParameterValues._process_symbol(self, symbol)
#     742     function = pybamm.Scalar(function_name, name=symbol.name)
#     743 elif callable(function_name):
#     744     # otherwise evaluate the function to create a new PyBaMM object
# --> 745     function = function_name(*new_children)
#     746 elif isinstance(
#     747     function_name, (pybamm.Interpolant, pybamm.InputParameter)
#     748 ) or (
#     749     isinstance(function_name, pybamm.Symbol)
#     750     and function_name.size_for_testing == 1
#     751 ):
#     752     function = function_name
#
# File ~/EEG (WSL)/Li-Si/Durdel2023.py:52, in silicon_ocp_lithiation_Durdel2023(sto)
#      50 silicon_lith_ocp_sto = [0.03869, 0.03869, 0.03869, 0.03869, 0.03965, 0.03965, 0.03965, 0.03965, 0.03985, 0.03985, 0.03965, 0.0392, 0.0392, 0.04061, 0.04061, 0.04061, 0.04158, 0.04254, 0.04158, 0.0435, 0.0435, 0.04447, 0.0464, 0.04736, 0.05025, 0.05121, 0.05411, 0.05989, 0.06663, 0.07434, 0.08013, 0.09555, 0.10229, 0.11386, 0.12831, 0.13892, 0.14566, 0.15723, 0.17265, 0.17747, 0.18999, 0.2006, 0.21216, 0.22758, 0.23818, 0.24493, 0.25553, 0.26517, 0.2748, 0.29119, 0.29601]
#      51 silicon_lith_ocp_volt = [0.994, 0.972, 0.95, 0.922, 0.9, 0.876, 0.854, 0.83, 0.77733, 0.73067, 0.806, 0.752, 0.70533, 0.68, 0.666, 0.644, 0.62, 0.596, 0.572, 0.54, 0.526, 0.504, 0.48, 0.456, 0.434, 0.412, 0.388, 0.356, 0.338, 0.322, 0.318, 0.306, 0.304, 0.298, 0.288, 0.282, 0.278, 0.274, 0.264, 0.262, 0.258, 0.252, 0.248, 0.238, 0.232, 0.23, 0.222, 0.214, 0.204, 0.19, 0.184]
# ---> 52 return pybamm.Interpolant(silicon_lith_ocp_sto, silicon_lith_ocp_volt, sto, name="silicon_lith_ocp", interpolator="cubic", extrapolate=False)
#
# File ~/miniconda3/envs/LiSi/lib/python3.11/site-packages/pybamm/expression_tree/interpolant.py:103, in Interpolant.__init__(self, x, y, children, name, interpolator, extrapolate, entries_string, _num_derivatives)
#     101         x: list[npt.NDArray[np.float64]] = [x]  # type: ignore[no-redef]
#     102     x2 = None
# --> 103     if x1.shape[0] != y.shape[0]:
#     104         raise ValueError(
#     105             "len(x1) should equal y=shape[0], "
#     106             f"but x1.shape={x1.shape} and y.shape={y.shape}"
#     107         )
#     108 # children should be a list not a symbol or a number
#
# AttributeError: 'float' object has no attribute 'shape'

# %%
pybamm.plot_voltage_components(solution)


sim.plot(output_variables=["Voltage [V]", 
                           "Current [A]",
                           "Negative primary particle surface concentration [mol.m-3]",
                           "Negative secondary particle surface concentration [mol.m-3]",
                           "Negative electrode potential [V]",
                           "Positive electrode potential [V]",
                           "X-averaged negative electrode secondary open-circuit potential [V]"
                           ])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=107.58414060219351, step=1.0758414060219352)…
